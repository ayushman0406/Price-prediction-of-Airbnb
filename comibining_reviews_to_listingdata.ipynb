# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushman0406/Price-prediction-of-Airbnb/blob/main/comibining_reviews_to_listingdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("commentcollab.csv")

# %%
df.head()
# Out:
#    listing_id  subjectivity  sentiment
# 0       17475      0.822500   0.702500
# 1       17475      0.405556   0.266667
# 2       17475      0.638333   0.367500
# 3       17475      0.674938   0.565370
# 4       17475      0.589841   0.422857

# %%
result_df = df.groupby('listing_id').mean().reset_index()

# %%
result_df.head(50)
# Out:
#     listing_id  subjectivity  sentiment
# 0        17475      0.631559   0.419558
# 1        18674      0.608874   0.391424
# 2        23197      0.594656   0.374013
# 3        32711      0.652872   0.443410
# 4        34241      0.490658   0.253972
# 5        34981      0.616271   0.423170
# 6        36763      0.644975   0.409447
# 7        40983      0.627217   0.339176
# 8        41952      0.622458   0.374884
# 9        46153      0.570082   0.434297
# 10       49968      0.660342   0.467574
# 11       68547      0.616077   0.422589
# 12       71520           NaN        NaN
# 13       71553      0.602441   0.320613
# 14       71736      0.654362   0.297335
# 15       72436      0.640670   0.439898
# 16       72793      0.619583   0.263333
# 17       72794      0.593790   0.272895
# 18       73683      0.631300   0.436701
# 19       75003      0.638034   0.301098
# 20       75411      0.627915   0.442329
# 21       80004      0.640227   0.381719
# ...

# %%
result_df.to_csv("consolidatedreviews.csv",index=False)

# %%
df1=pd.read_csv("consolidatedreviews.csv")

# %%
df2=pd.read_csv("listingchange.csv")

# %%
merged_df = pd.merge(df1, df2, on='listing_id', how='left')

# %%
df1.head()
# Out:
#    listing_id  subjectivity  sentiment
# 0       17475      0.631559   0.419558
# 1       18674      0.608874   0.391424
# 2       23197      0.594656   0.374013
# 3       32711      0.652872   0.443410
# 4       34241      0.490658   0.253972

# %%
df2.head()
# Out:
#    listing_id  host_since host_respose_time host_response_rate  \
# 0     17475.0  25-12-2009              hour               100%
# 1     18674.0  19-01-2010              hour                97%
# 2    198958.0  15-08-2011              hour               100%
# 3    199794.0  14-03-2011         few hours                90%
# 4     23197.0  09-03-2010              hour               100%
#
#   host_acceptance_rate  host_is_superhost  host_listings_count  \
# 0                  96%                1.0                    1
# 1                  87%                0.0                   47
# 2                  98%                0.0                   14
# 3                  66%                1.0                    1
# 4                  95%                1.0                    6
#
#    host_total_listings_count  host_has_profile_pic  host_identity_verified  \
# 0                          5                     1                       1
# ...

# %%
merged_df.head()
# Out:
#    listing_id  subjectivity  sentiment  host_since host_respose_time  \
# 0       17475      0.631559   0.419558  25-12-2009              hour
# 1       18674      0.608874   0.391424  19-01-2010              hour
# 2       23197      0.594656   0.374013  09-03-2010              hour
# 3       32711      0.652872   0.443410  31-05-2010              hour
# 4       34241      0.490658   0.253972  24-01-2010              hour
#
#   host_response_rate host_acceptance_rate  host_is_superhost  \
# 0               100%                  96%                1.0
# 1                97%                  87%                0.0
# 2               100%                  95%                1.0
# 3               100%                 100%                0.0
# 4               100%                  99%                0.0
#
#    host_listings_count  host_total_listings_count  ...  \
# 0                  1.0                        5.0  ...
# 1                 47.0                       48.0  ...
# ...

# %%
merged_df.to_csv("machinelearning.csv",index=False)
