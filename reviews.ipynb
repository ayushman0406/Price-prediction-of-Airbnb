# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushman0406/Price-prediction-of-Airbnb/blob/main/reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

# %%
df = pd.read_csv("review.csv")


def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# %%
df['comments'] = df['comments'].astype(str)

# %%
df['sentiment'] = df['comments'].apply(get_sentiment)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592040 entries, 0 to 592039
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   listing_id    592040 non-null  int64
#  1   comments      592040 non-null  object
#  2   subjectivity  592040 non-null  float64
#  3   sentiment     592040 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 18.1+ MB

# %%
df.head()
# Out:
#    listing_id                                           comments  \
# 0       17475  Excellent host, beautiful apartment, great loc...
# 1       17475  Luca is very personable, and the views are exa...
# 2       17475  I am glad we found Luca's apt for our stay in ...
# 3       17475  I should start by saying we really did not wan...
# 4       17475  Luca was a very gracious host and took efforts...
#
#    subjectivity  sentiment
# 0      0.822500   0.702500
# 1      0.405556   0.266667
# 2      0.638333   0.367500
# 3      0.674938   0.565370
# 4      0.589841   0.422857

# %%
def get_subjectivity(text):
    analysis = TextBlob(text)
    return analysis.sentiment.subjectivity

# %%
df['subjectivity'] = df['comments'].apply(get_subjectivity)

# %%
df.head()
# Out:
#    listing_id                                           comments  subjectivity
# 0       17475  Excellent host, beautiful apartment, great loc...      0.822500
# 1       17475  Luca is very personable, and the views are exa...      0.405556
# 2       17475  I am glad we found Luca's apt for our stay in ...      0.638333
# 3       17475  I should start by saying we really did not wan...      0.674938
# 4       17475  Luca was a very gracious host and took efforts...      0.589841

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592040 entries, 0 to 592039
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   listing_id    592040 non-null  int64
#  1   comments      592040 non-null  object
#  2   subjectivity  592040 non-null  float64
#  3   sentiment     592040 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 18.1+ MB
